# %%
import pandas as pd
import random
import os
import numpy as np

from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier

# %%
raw_data = pd.read_csv('./dataset/train.csv')
data = raw_data.copy()

# %%
data= data.drop(columns=['father','mother','gender','id'])
data = data.rename(columns = { 'class' : 'cl'})

# %%
data.query('cl == "A"')
# Out:
#      trait SNP_01 SNP_02 SNP_03 SNP_04 SNP_05 SNP_06 SNP_07 SNP_08 SNP_09  \
# 3        1    A A    G G    A A    G A    A A    G G    G G    A A    G G
# 15       1    A A    G G    A A    G G    A A    G G    G G    A A    G G
# 16       1    A A    G G    A A    G G    A A    G G    G G    A A    G A
# 17       1    A G    A G    A A    G G    C A    A G    G A    A A    G A
# 18       1    A A    G G    A A    G A    A A    G G    G G    A A    G A
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 248      1    A G    G G    A A    G G    A A    G G    G G    A A    G G
# 250      1    A G    G G    A A    G G    A A    G G    G G    A A    G G
# 253      1    A A    G G    A A    G G    A A    G G    G G    G A    G A
# 259      1    A G    G G    A A    G A    A A    A G    G G    G A    G A
# 260      1    A A    G G    A A    G A    A A    G G    G G    A A    G A
#
#     SNP_10 SNP_11 SNP_12 SNP_13 SNP_14 SNP_15 cl
# ...

# %%
for x in range(1,16):
    if x < 10:
        print('SNP{}'.format(x),data.query('cl == "A"')['SNP_0{}'.format(x)].unique())
    else :
        print('SNP{}'.format(x), data.query('cl == "A"')['SNP_{}'.format(x)].unique())
# Out:
# SNP1 ['A A' 'A G' 'G G']
# SNP2 ['G G' 'A G']
# SNP3 ['A A']
# SNP4 ['G A' 'G G' 'A A']
# SNP5 ['A A' 'C A']
# SNP6 ['G G' 'A G']
# SNP7 ['G G' 'G A']
# SNP8 ['A A' 'G A']
# SNP9 ['G G' 'G A' 'A A']
# SNP10 ['A G' 'G G' 'A A']
# SNP11 ['G G' 'A G']
# SNP12 ['G G' 'G A' 'A A']
# SNP13 ['G G' 'A G']
# SNP14 ['A A' 'C C' 'C A']
# SNP15 ['G G' 'G A' 'A A']

# %%
data.query('cl == "B"')
for x in range(1,16):
    if x < 10:
        print('SNP{}'.format(x),data.query('cl == "B"')['SNP_0{}'.format(x)].unique())
    else :
        print('SNP{}'.format(x), data.query('cl == "B"')['SNP_{}'.format(x)].unique())
# Out:
# SNP1 ['G G' 'A G']
# SNP2 ['A G' 'G G' 'A A']
# SNP3 ['A A' 'C A' 'C C']
# SNP4 ['G A' 'A A' 'G G']
# SNP5 ['C A' 'C C' 'A A']
# SNP6 ['A A' 'G G' 'A G']
# SNP7 ['A A' 'G A']
# SNP8 ['G G' 'G A' 'A A']
# SNP9 ['A A' 'G A' 'G G']
# SNP10 ['G G' 'A G']
# SNP11 ['A G' 'A A' 'G G']
# SNP12 ['A A' 'G A' 'G G']
# SNP13 ['A A' 'A G' 'G G']
# SNP14 ['A A']
# SNP15 ['A A' 'G G' 'G A']

# %%
data.query('cl == "C"')
# Out:
#      trait SNP_01 SNP_02 SNP_03 SNP_04 SNP_05 SNP_06 SNP_07 SNP_08 SNP_09  \
# 1        2    A G    A G    C A    A A    A A    A G    A A    G A    A A
# 4        2    G G    G G    C C    A A    C C    A A    A A    A A    A A
# 9        2    G G    G G    C A    A A    C C    A G    A A    G G    A A
# 12       2    G G    A G    C C    A A    A A    A G    A A    G A    A A
# 13       2    A G    A A    C A    G A    A A    G G    A A    A A    A A
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 238      2    A G    A G    C C    A A    A A    A G    A A    G A    A A
# 241      2    A G    A G    A A    A A    A A    A G    G A    G A    A A
# 242      2    G G    A G    C A    A A    C A    A G    A A    G A    A A
# 251      2    G G    A A    C C    A A    A A    A A    A A    G G    A A
# 258      2    G G    A A    C A    A A    A A    A G    G A    G A    A A
#
#     SNP_10 SNP_11 SNP_12 SNP_13 SNP_14 SNP_15 cl
# ...

# %%
for x in range(1,16):
    if x < 10:
        print('SNP{}'.format(x),data.query('cl == "C"')['SNP_0{}'.format(x)].unique())
    else :
        print('SNP{}'.format(x), data.query('cl == "C"')['SNP_{}'.format(x)].unique())
# Out:
# SNP1 ['A G' 'G G' 'A A']
# SNP2 ['A G' 'G G' 'A A']
# SNP3 ['C A' 'C C' 'A A']
# SNP4 ['A A' 'G A']
# SNP5 ['A A' 'C C' 'C A']
# SNP6 ['A G' 'A A' 'G G']
# SNP7 ['A A' 'G A']
# SNP8 ['G A' 'A A' 'G G']
# SNP9 ['A A' 'G A']
# SNP10 ['A G' 'G G' 'A A']
# SNP11 ['A A' 'A G' 'G G']
# SNP12 ['G A' 'A A' 'G G']
# SNP13 ['G G' 'A G' 'A A']
# SNP14 ['A A' 'C A' 'C C']
# SNP15 ['A A' 'G A' 'G G']

# %%
for x in range(1,16):
    if x < 10:
        print('SNP_B{}'.format(x),data.query('cl == "B"')['SNP_0{}'.format(x)].unique())
        print('SNP_C{}'.format(x),data.query('cl == "C"')['SNP_0{}'.format(x)].unique())
    else :
        print('SNP_B{}'.format(x),data.query('cl == "B"')['SNP_{}'.format(x)].unique())
        print('SNP_C{}'.format(x),data.query('cl == "C"')['SNP_{}'.format(x)].unique())
# Out:
# SNP_B1 ['G G' 'A G']
# SNP_C1 ['A G' 'G G' 'A A']
# SNP_B2 ['A G' 'G G' 'A A']
# SNP_C2 ['A G' 'G G' 'A A']
# SNP_B3 ['A A' 'C A' 'C C']
# SNP_C3 ['C A' 'C C' 'A A']
# SNP_B4 ['G A' 'A A' 'G G']
# SNP_C4 ['A A' 'G A']
# SNP_B5 ['C A' 'C C' 'A A']
# SNP_C5 ['A A' 'C C' 'C A']
# SNP_B6 ['A A' 'G G' 'A G']
# SNP_C6 ['A G' 'A A' 'G G']
# SNP_B7 ['A A' 'G A']
# SNP_C7 ['A A' 'G A']
# SNP_B8 ['G G' 'G A' 'A A']
# SNP_C8 ['G A' 'A A' 'G G']
# SNP_B9 ['A A' 'G A' 'G G']
# SNP_C9 ['A A' 'G A']
# SNP_B10 ['G G' 'A G']
# SNP_C10 ['A G' 'G G' 'A A']
# SNP_B11 ['A G' 'A A' 'G G']
# SNP_C11 ['A A' 'A G' 'G G']
# SNP_B12 ['A A' 'G A' 'G G']
# SNP_C12 ['G A' 'A A' 'G G']
# SNP_B13 ['A A' 'A G' 'G G']
# SNP_C13 ['G G' 'A G' 'A A']
# SNP_B14 ['A A']
# SNP_C14 ['A A' 'C A' 'C C']
# SNP_B15 ['A A' 'G G' 'G A']
# SNP_C15 ['A A' 'G A' 'G G']
